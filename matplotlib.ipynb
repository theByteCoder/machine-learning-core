# %%
from matplotlib import pyplot as plt

# %%
x = ['a', 'b', 'c', 'd']
y = [2, 4, 8, 11]

# %%
plt.plot(x, y)
plt.show()

# %%
plt.bar(x, y)
plt.show()

# %%
c = ['r', 'y', 'g', 'b']

plt.bar(x, y, color=c)
plt.show()
